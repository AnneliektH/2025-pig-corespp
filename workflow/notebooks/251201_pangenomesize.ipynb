# %% [markdown]
# # get sizes of pangenomes before vs after adding new binned content

# %%
import pandas as pd
import glob

files = glob.glob("/group/ctbrowngrp2/amhorst/2025-pig-corespp/results/pangenome/*/*sizes.tsv")

df = pd.concat((pd.read_csv(f, sep="\t") for f in files), ignore_index=True)

# %%
df
# Out:
#                                   species  gtdb.k31.pang  gtdb+mags.k31  \
# 0        Butyricicoccus_A_intestinisimiae          11680          18281
# 1           Cryptobacteroides_sp900546925          14714          22680
# 2                  Prevotella_sp002251295          12466          29758
# 3                 Bariatricus_sp004560705           6981          22826
# 4                    JALFVM01_sp022787145           5073          21780
# 5                     Gemmiger_qucibialis          39128          45438
# 6                     UBA2868_sp004552595           7344          24695
# 7                    Phocaeicola_vulgatus         135044         135320
# 8                    Oscillibacter_segnis          30031          30031
# 9   Phascolarctobacterium_A_succinatutens           7415          10355
# 10                Roseburia_inulinivorans          46866          48501
# 11                     Holdemanella_porci           8412          13462
# 12               Lactobacillus_amylovorus          17138          28151
# 13          Mogibacterium_A_kristiansenii          10715          18310
# 14                   Fimisoma_sp002320005           4925           7813
# 15                   JAFBIX01_sp021531895           6945          13809
# 16               Sodaliphilus_sp004557565          31306          41435
# 17                 Prevotella_sp000434975          31702          34713
#
#     gtdb+mags.k31.novel_content
# 0                          6601
# 1                          7966
# 2                         17292
# 3                         15845
# 4                         16707
# 5                          6310
# 6                         17351
# 7                           276
# 8                             0
# 9                          2940
# 10                         1635
# 11                         5050
# 12                        11013
# 13                         7595
# 14                         2888
# 15                         6864
# 16                        10129
# 17                         3011
