# %% [markdown]
# # Ran gather with decontaminated db.
# - Found 17 spp in 99% of genomes.
# - Extracted SCGs with FetchMGs (https://github.com/motu-tool/fetchMGs)
# - How many of the metaGs have a signal of the single copy marker genes

# %%
# imports
import pandas as pd

# %%
# open df 
dfgather = pd.read_csv('/group/ctbrowngrp2/amhorst/2025-pig-corespp/results/csv_files/251201_99core.10000kb.csv')
dfgather
# Out:
#                                            match_name   len
# 0   GCF_938046715 s__Phascolarctobacterium_A succi...  3189
# 1      GCA_037297645 s__Cryptobacteroides sp900546925  3190
# 2               GCA_900539495 s__Oscillibacter segnis  3183
# 3               GCA_034115705 s__JALFVM01 sp022787145  3187
# 4            GCA_029378305 s__Bariatricus sp004560705  3199
# 5                GCA_041324565 s__Gemmiger qucibialis  3185
# 6      GCA_036550655 s__Mogibacterium_A kristiansenii  3197
# 7               GCA_034122665 s__Phocaeicola vulgatus  3193
# 8                GCA_945229155 s__UBA2868 sp004552595  3204
# 9                 GCA_945912825 s__Holdemanella porci  3189
# 10              GCA_945829385 s__Fimisoma sp002320005  3188
# 11          GCA_004552585 s__Lactobacillus amylovorus  3210
# 12              GCA_945876855 s__JAFBIX01 sp021531895  3198
# 13  GCA_036302005 s__Butyricicoccus_A intestinisimiae  3183
# 14            GCA_034114805 s__Prevotella sp002251295  3189
# 15           GCA_037266765 s__Roseburia inulinivorans  3186
# 16                  GCF_946909825 s__Escherichia coli  3216
# 17            GCA_021620945 s__Prevotella sp000434975  3188
# 18          GCA_022779425 s__Sodaliphilus sp004557565  3195

# %%
df_sc = pd.read_csv('/group/ctbrowngrp2/amhorst/2025-pig-corespp/results/single_copy_genes/251201_manysearch.3216.SCG.csv')
df_sc = df_sc[['match_name', 'query_name', 'max_containment']]

# %%
df_sc["query_name"] = df_sc["query_name"].str.replace(r".*/", "", regex=True)

df_sc['match_name'].nunique()
# Out:
# 3217

# %%
df_sc
# Out:
#         match_name                       query_name  max_containment
# 0      SRR11125219     Oscillibacter_segnis.SCG.fna         0.025815
# 1      SRR11125219  Roseburia_inulinivorans.SCG.fna         0.024113
# 2      SRR11125219   Prevotella_sp002251295.SCG.fna         0.045491
# 3      SRR11125219      Gemmiger_qucibialis.SCG.fna         0.020345
# 4      SRR11125219      UBA2868_sp004552595.SCG.fna         0.034497
# ...            ...                              ...              ...
# 57896  SRR17241510     Fimisoma_sp002320005.SCG.fna         0.591466
# 57897  SRR17241510     Phocaeicola_vulgatus.SCG.fna         0.029116
# 57898  SRR17241510       Holdemanella_porci.SCG.fna         0.238278
# 57899  SRR17241510   Prevotella_sp000434975.SCG.fna         0.163902
# 57900  SRR17241510     JALFVM01_sp022787145.SCG.fna         0.391666
#
# [57901 rows x 3 columns]

# %%
ids = pd.read_csv("/group/ctbrowngrp2/amhorst/2025-pig-corespp/resources/metag-wort-hq.3217.txt", header=None)[0]

df_sc = df_sc[df_sc["match_name"].isin(ids)]

# %%
df_sc['query_name'].value_counts()
# Out:
# query_name
# Oscillibacter_segnis.SCG.fna                     3216
# Roseburia_inulinivorans.SCG.fna                  3216
# Prevotella_sp002251295.SCG.fna                   3216
# Gemmiger_qucibialis.SCG.fna                      3216
# UBA2868_sp004552595.SCG.fna                      3216
# JAFBIX01_sp021531895.SCG.fna                     3216
# Phascolarctobacterium_A_succinatutens.SCG.fna    3216
# Sodaliphilus_sp004557565.SCG.fna                 3216
# Cryptobacteroides_sp900546925.SCG.fna            3216
# Lactobacillus_amylovorus.SCG.fna                 3216
# Phocaeicola_vulgatus.SCG.fna                     3216
# Bariatricus_sp004560705.SCG.fna                  3216
# Mogibacterium_A_kristiansenii.SCG.fna            3216
# JALFVM01_sp022787145.SCG.fna                     3216
# Prevotella_sp000434975.SCG.fna                   3216
# Holdemanella_porci.SCG.fna                       3215
# Fimisoma_sp002320005.SCG.fna                     3214
# Butyricicoccus_A_intestinisimiae.SCG.fna         3214
# Name: count, dtype: int64
